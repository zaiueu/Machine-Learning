# %% [markdown]
# UAS

# %% [markdown]
# Nama        : Zaidan Jainul Insan
# Nim         : 20220801421
# Prodi       : Teknik Informatika
# Mata Kuliah : Machine Learning

# %% [markdown]
# ESSAY

# %% [markdown]
# 1. Jelaskan bagaimana memanfaatkan Machine Learning untuk Call API
# 2. Jelaskan apa yang dimaksud dengan unsupervised learning
# 3. Sebutkan beberapa tools yang di gunakan untuk mengolah machine learning

# %% [markdown]
# 1.	Machine Learning dapat dimanfaatkan untuk mengoptimalkan pemanggilan API dengan berbagai cara yang inovatif. Model ML dapat dilatih untuk memprediksi pola penggunaan API, memungkinkan pre-fetching data yang kemungkinan besar akan diminta, sehingga mengurangi latensi dan meningkatkan responsivitas sistem. Algoritma klasifikasi dapat digunakan untuk memprioritaskan permintaan API berdasarkan urgensi atau nilai bisnis, memastikan sumber daya dialokasikan secara efisien. Deteksi anomali berbasis ML dapat mengidentifikasi pola tidak biasa dalam respons API, memungkinkan penanganan cepat terhadap potensi masalah sebelum berdampak signifikan pada pengguna.
#
#     Teknik pembelajaran penguatan dapat dioptimalkan parameter panggilan API seperti ukuran batch, frekuensi polling, atau strategi caching, secara dinamis menyesuaikan dengan kondisi jaringan dan beban server untuk meningkatkan kinerja keseluruhan. ML juga dapat digunakan untuk menganalisis log API, mengidentifikasi tren penggunaan, dan memberikan wawasan untuk pengembangan API di masa depan. Dalam konteks keamanan, model ML dapat mendeteksi dan mencegah penyalahgunaan API dengan mengidentifikasi pola mencurigakan dalam permintaan. Terakhir, teknik NLP dapat digunakan untuk meningkatkan pemahaman dan pemrosesan permintaan API berbasis bahasa alami, membuat antarmuka API lebih intuitif dan mudah digunakan.

# %% [markdown]
# 2.	Unsupervised learning adalah salah satu cabang utama dalam machine learning di mana algoritma dilatih menggunakan data yang tidak berlabel atau tidak memiliki output yang ditentukan sebelumnya. Tujuan utamanya adalah menemukan pola, struktur, atau hubungan yang tersembunyi dalam data tanpa panduan eksternal. Dalam pendekatan ini, model belajar untuk mengorganisir dan memahami data berdasarkan fitur dan karakteristik intrinsiknya, tanpa memerlukan intervensi manusia untuk memberikan label atau klasifikasi.
#
#     Metode unsupervised learning umumnya melibatkan teknik seperti clustering, di mana data dikelompokkan berdasarkan kesamaan, dan pengurangan dimensi, yang bertujuan untuk menemukan representasi data yang lebih sederhana namun tetap informatif. Aplikasi praktis dari unsupervised learning mencakup segmentasi pelanggan dalam pemasaran, deteksi anomali dalam sistem keamanan, dan pemrosesan bahasa alami untuk menemukan topik dalam teks yang tidak terstruktur. Keunggulan utama pendekatan ini adalah kemampuannya untuk mengungkap wawasan yang tidak terduga dari data kompleks tanpa memerlukan pelabelan manual yang mahal dan memakan waktu.

# %% [markdown]
# 3.	beberapa tools yang umum digunakan untuk mengolah machine learning:
#
#     1) Python: Bahasa pemrograman yang sangat populer untuk ML.
#     2)	TensorFlow: Library open-source untuk komputasi numerik dan ML skala besar.
#     3)	PyTorch: Framework ML yang fleksibel dan dinamis.
#     4)	Scikit-learn: Library Python untuk ML klasik.
#     5)	Keras: API neural network tingkat tinggi yang berjalan di atas TensorFlow.
#     6)	NLTK: Toolkit untuk pemrosesan bahasa alami.
#     7)	OpenCV: Library untuk computer vision.
#     8)	R: Bahasa pemrograman untuk analisis statistik dan ML.
#     9)	Jupyter Notebook: Lingkungan interaktif untuk data science.
#     10)	Apache Spark: Framework untuk pemrosesan data besar-besaran.
#     11)	Pandas: Library Python untuk manipulasi dan analisis data.
#     12)	NumPy: Library untuk komputasi numerik di Python.
#     13)	Matplotlib: Library Python untuk visualisasi data.

# %% [markdown]
# SOAL STUDY KASUS

# %% [markdown]
# Dengan menggunakan Jupyter Notebook lakukan pengolahan text dari url berikut ini
# https://shared.djambred.my.id/uas-nim-ganjil.txt
# olah text tersebut sehingga dapat mengeluarkan hasil wordcloud, barplot frekuensi
# kata yang sering digunakan, plot terkait sentiment feel text tersebut.

# %%
# Import library yang diperlukan
import pandas as pd
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from collections import Counter
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk

# resources yang diperlukan
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('vader_lexicon')

# Teks dari url
text = """Long long time ago, in England in Sherwood Forest lived Robin Hood. 
When he was a boy , he had been cheated by a few noblemen. 
Since then he had decided that he would rob the rich and give what he got to the poor.
The Sheriff of Nottingham had made an advertisement that he would give many rewards for the capture of Robin Hood, nobody had ever caught him. 
It was because Robin Hood had a number of friends who served him. They acted as informers. 
When the Sheriff had any plan to catch him, they would warn Robin Hood.
Many rich people were scared of going through Sherwood Forest because they knew that Robin Hood would attack them. 
The Sheriff couldn't stand it anymore. 
Then he went to ask for the king's help. 
However, the king refused to send any of his men to help in the capture of Robbin Hood.
One day The Sheriff and the noblemen held a competition to choose the best shooter in Nottingham. 
It was for capturing Robin Hood. 
Robin Hood was an excellent shooter. 
Therefore, Robin Hood would participate in the competition to prove that he was the best. 
He had been warned by his servant, but Robin wasn't willing to listen.
The competition began. 
William, The Sheriff man, and the man in green were trying for the first prize. 
it was time for the last arrow to be shot. 
The winner of this round would be declared the best shooter in Nottingham. 
William could shot very close to the center. 
Then the man in green's turn made the crowd cheer hysterically. 
His arrow went through William's arrows and the center of the target. 
Then he shot two more arrows towards the chair on which the Sheriff sat. 
No doubt that the man in green was Robin Hood. 
immediately Robin Hood pulled of his black wig and then jumped over a wall onto his waiting horse and was gone. 
The Sheriff shouted to his men to catch him, but it was to late. 
Robin Hood escaped successfully."""

# Tokenisasi dan pembersihan teks
stop_words = set(stopwords.words('english'))
words = word_tokenize(text.lower())
cleaned_words = [word for word in words if word.isalnum() and word not in stop_words]

# Wordcloud
wordcloud = WordCloud(width=800, height=400, background_color='white').generate(' '.join(cleaned_words))
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.title('Wordcloud')
plt.show()

# Barplot frekuensi kata
word_freq = Counter(cleaned_words)
top_words = dict(word_freq.most_common(15))
plt.figure(figsize=(10, 5))
plt.bar(top_words.keys(), top_words.values())
plt.title('Top 15 Most Frequent Words')
plt.xlabel('Words')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# Analisis sentimen
sia = SentimentIntensityAnalyzer()
sentences = text.split('.')
sentiments = [sia.polarity_scores(sentence)['compound'] for sentence in sentences]

plt.figure(figsize=(10, 5))
plt.plot(sentiments)
plt.title('Sentiment Flow')
plt.xlabel('Sentence')
plt.ylabel('Sentiment Score')
plt.axhline(y=0, color='r', linestyle='--')
plt.show()
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\zaida\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\zaida\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\zaida\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
